# %% [markdown]
# # Web Scrapping

# %% [markdown]
# Web scraping, web harvesting, or web data extraction is data scraping used for extracting data from websites. The web scraping software may directly access the World Wide Web using the Hypertext Transfer Protocol or a web browser.

# %% [markdown]
# For this class: **BeautifulSoup**
#
# Beautifulsoup is aPython library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It has limited that cannot be used for dynamic websites that include Javascript. However, we will use Selenium to cover this drawback.

# %% [markdown]
# Installation in conda prompt
# - pip install bs4
# - pip install requests
# - pip install selenium

# %% [markdown]
# ### Scrapping data dari Gramedia

# %%
import requests
page = requests.get("https://www.gramedia.com/categories/buku")
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome('../../../../../chromedriver.exe')

url="https://www.gramedia.com/categories/buku"
driver.get(url)
html = driver.page_source

soup = BeautifulSoup(html, "html.parser")
print(soup.prettify()[:700])
# Out:
# C:\Users\Kurim\AppData\Local\Temp\ipykernel_12500\2750514676.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('../../../../../chromedriver.exe')
# <html class="" lang="id">
#  <head>
#   <base href="/"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#281e5a" name="theme-color"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/assets/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="manifest.json" rel="manifest"/>
#   <link href="/assets/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="z91Vp6ZYo9UoX5D4ur6i4Lrl0l1j3DDoCH08fD3n53g" name="google-site-verification"/>
#   <meta content="810657685650228" property="fb:app_id"/>
#   <style>
#    .async-hide {
#         opacity: 0 !important
#     }
#   </style>
#   <script async="" src="https://app.

# %% [markdown]
# ``` <div _ngcontent-web-gramedia-c26 class="list-title">Biru Pram Frasa</div> ```

# %%
soup.find_all('div',{"class":"list-title"})
# Out:
# [<div _ngcontent-web-gramedia-c26="" class="list-title">Cabaca : Cara Cepat Pintar Membaca Untuk Anak 4-6 Tahun</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Living Clean : Gaya Hidup Minim Toksin!</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Biru Pram Frasa</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Uncensored Blak-Blakan Soal Pasutri (New Cover)</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Hilangnya Sajadah Ayah</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Komik Next G: Misteri Ruang Ipa</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Indonesia X-Files</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Laskar &amp; Jingga</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">The King 2023 Soshum : Bedah Kisi2 Sbmptn &amp; Um Mandiri</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">FSA Komik Pendidikan Vitamin : Menjaga Kesehatan Tubuh Dan Hati</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">FSA Real Account 04</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Renungan Sufi Membuka Tirai Kegaiban</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Mereka Yang Tak Pernah Mati</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Injury Time Ujian Sekolah Sd/Mi 2023</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Parenting Detox</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Bebaskan Aku Dari Alergi, Panduan Ortu Kekinian Vol. 2</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Ergonomi Dinamika Beban Kerja</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">FSA Sang Pemenang Berdiri Sendirian (The Winner Stands Alone)</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Beternak Magot</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Populasi - Sampel, Teknik Sampling&amp;Bias Dalam Penelitian</div>]

# %%
for div_tag in soup.find_all('div',{"class":"list-title"}):
    print(div_tag.get_text())
# Out:
# Cabaca : Cara Cepat Pintar Membaca Untuk Anak 4-6 Tahun
# Living Clean : Gaya Hidup Minim Toksin!
# Biru Pram Frasa
# Uncensored Blak-Blakan Soal Pasutri (New Cover)
# Hilangnya Sajadah Ayah
# Komik Next G: Misteri Ruang Ipa
# Indonesia X-Files
# Laskar & Jingga
# The King 2023 Soshum : Bedah Kisi2 Sbmptn & Um Mandiri
# FSA Komik Pendidikan Vitamin : Menjaga Kesehatan Tubuh Dan Hati
# FSA Real Account 04
# Renungan Sufi Membuka Tirai Kegaiban
# Mereka Yang Tak Pernah Mati
# Injury Time Ujian Sekolah Sd/Mi 2023
# Parenting Detox
# Bebaskan Aku Dari Alergi, Panduan Ortu Kekinian Vol. 2
# Ergonomi Dinamika Beban Kerja
# FSA Sang Pemenang Berdiri Sendirian (The Winner Stands Alone)
# Beternak Magot
# Populasi - Sampel, Teknik Sampling&Bias Dalam Penelitian

# %%
# Putting all the html infos as dataframe
import pandas as pd

data = pd.DataFrame()

data['Title'] = [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
data['Author'] = [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
data['Price'] = [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
data['Image'] = [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

links = []
for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
    try:
        links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
    except:
        pass

data['Link'] = links

data
# Out:
#                                                 Title  \
# 0   Cabaca : Cara Cepat Pintar Membaca Untuk Anak ...
# 1             Living Clean : Gaya Hidup Minim Toksin!
# 2                                     Biru Pram Frasa
# 3     Uncensored Blak-Blakan Soal Pasutri (New Cover)
# 4                              Hilangnya Sajadah Ayah
# 5                     Komik Next G: Misteri Ruang Ipa
# 6                                   Indonesia X-Files
# 7                                     Laskar & Jingga
# 8   The King 2023 Soshum : Bedah Kisi2 Sbmptn & Um...
# 9   FSA Komik Pendidikan Vitamin : Menjaga Kesehat...
# 10                                FSA Real Account 04
# 11               Renungan Sufi Membuka Tirai Kegaiban
# 12                        Mereka Yang Tak Pernah Mati
# 13               Injury Time Ujian Sekolah Sd/Mi 2023
# 14                                    Parenting Detox
# 15  Bebaskan Aku Dari Alergi, Panduan Ortu Kekinia...
# 16                      Ergonomi Dinamika Beban Kerja
# 17  FSA Sang Pemenang Berdiri Sendirian (The Winne...
# 18                                     Beternak Magot
# 19  Populasi - Sampel, Teknik Sampling&Bias Dalam ...
#
#                                 Author       Price  \
# 0                  FANY NOVIA CAHYANI    Rp 59.000
# 1              Inge Tumiwa - Bachrens    Rp 88.000
# 2                       MEGAKATA None    Rp 88.000
# 3                         @OLEVELOVE    Rp 109.000
# 4                      Benny Rhamdani    Rp 64.000
# 5    Sayyida Mafaazaa Salsabila, dkk.    Rp 39.000
# 6      dr. Abdul Mun'im Idries, Sp.F.    Rp 98.000
# 7                            Tresia .    Rp 99.000
# 8              Forum Tentor Indonesia   Rp 240.000
# 9            TIM PRODUKSI KBS VITAMIN   Rp 148.000
# 10           Okushou,Shizumu Watanabe    Rp 25.000
# 11                 Jalaluddin Rakhmat    Rp 99.000
# 12                  Emha Ainun Nadjib    Rp 79.000
# 13         RENATA KILIA,S.PD. DAN TIM   Rp 130.000
# 14                     Angga Setyawan    Rp 89.000
# 15   Dr. Vicka Farah Diba M.Sc.,Sp.A.    Rp 79.000
# 16    Tjokorda Bagus Putra Marhaendra    Rp 69.000
# 17                       Paulo Coelho    Rp 90.000
# 18                     Ediwarman None    Rp 74.000
# 19                   I Ketut Swarjana    Rp 56.000
#
#                                                 Image  \
# 0   https://cdn.gramedia.com/uploads/items/111_HOS...
# 1                  /assets/default-images/product.png
# 2   https://cdn.gramedia.com/uploads/items/Biru_Pr...
# 3                  /assets/default-images/product.png
# 4   https://cdn.gramedia.com/uploads/items/Hilangn...
# 5                  /assets/default-images/product.png
# 6   https://cdn.gramedia.com/uploads/items/Indones...
# 7                  /assets/default-images/product.png
# 8                  /assets/default-images/product.png
# 9   https://cdn.gramedia.com/uploads/items/FSA_Kom...
# 10  https://cdn.gramedia.com/uploads/items/FSA_Rea...
# 11                 /assets/default-images/product.png
# 12  https://cdn.gramedia.com/uploads/items/Mereka_...
# 13                 /assets/default-images/product.png
# 14  https://cdn.gramedia.com/uploads/items/Parenti...
# 15                 /assets/default-images/product.png
# 16                 /assets/default-images/product.png
# 17                 /assets/default-images/product.png
# 18                 /assets/default-images/product.png
# 19                 /assets/default-images/product.png
#
#                                                  Link
# 0   https://www.gramedia.com/products/cabaca-cara-...
# 1   https://www.gramedia.com/products/living-clean...
# 2   https://www.gramedia.com/products/biru-pram-frasa
# 3   https://www.gramedia.com/products/uncensored-b...
# 4   https://www.gramedia.com/products/hilangnya-sa...
# 5   https://www.gramedia.com/products/komik-next-g...
# 6   https://www.gramedia.com/products/indonesia-x-...
# 7     https://www.gramedia.com/products/laskar-jingga
# 8   https://www.gramedia.com/products/the-king-202...
# 9   https://www.gramedia.com/products/fsa-komik-pe...
# 10  https://www.gramedia.com/products/fsa-real-acc...
# 11  https://www.gramedia.com/products/renungan-suf...
# 12  https://www.gramedia.com/products/mereka-yang-...
# 13  https://www.gramedia.com/products/injury-time-...
# 14  https://www.gramedia.com/products/parenting-detox
# 15  https://www.gramedia.com/products/bebaskan-aku...
# 16  https://www.gramedia.com/products/ergonomi-din...
# 17  https://www.gramedia.com/products/fsa-sang-pem...
# 18   https://www.gramedia.com/products/beternak-magot
# 19  https://www.gramedia.com/products/populasi-sam...

# %%
# Multipage Table
title = []
author = []
price = []
image = []
Links = []

driver = webdriver.Chrome('../../../../../chromedriver.exe')

for i in range(1,21):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    title += [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
    author += [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
    price += [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
    image += [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

    links = []
    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
        except:
            pass
    Links += links

data_multipage = pd.DataFrame()
data_multipage['Title'] = title
data_multipage['Author'] = author
data_multipage['Price'] = price
data_multipage['Image'] = image
data_multipage['Link'] = Links

data_multipage
# Out:
# C:\Users\Kurim\AppData\Local\Temp\ipykernel_12500\2743587465.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('../../../../../chromedriver.exe')
#                                                  Title  \
# 0    Cabaca : Cara Cepat Pintar Membaca Untuk Anak ...
# 1              Living Clean : Gaya Hidup Minim Toksin!
# 2                                      Biru Pram Frasa
# 3      Uncensored Blak-Blakan Soal Pasutri (New Cover)
# 4                               Hilangnya Sajadah Ayah
# ..                                                 ...
# 135  Sd Kl 4 Pembelajaran Bahasa Mandarin Interakti...
# 136                       99 Kekuatan Berfikir Positif
# 137                                   Bumi Dan Lukanya
# 138  Experiential Based Learning, Pembelajaran Berb...
# 139  Sd Kl 2 Pembelajaran Bahasa Mandarin Interakti...
#
#                                                 Author       Price  \
# 0                                  FANY NOVIA CAHYANI    Rp 59.000
# 1                              Inge Tumiwa - Bachrens    Rp 88.000
# 2                                       MEGAKATA None    Rp 88.000
# 3                                         @OLEVELOVE    Rp 109.000
# 4                                      Benny Rhamdani    Rp 64.000
# ..                                                 ...         ...
# 135                                           Yi Ying    Rp 82.000
# 136                                     Aning Naafiah    Rp 50.000
# 137                                                      Rp 89.500
# 138   Ismijarti Juni Susanti Prof. Richardus Eko In...   Rp 39.000
# 139                                           YI YING    Rp 66.000
#
#                                                  Image  \
# 0    https://cdn.gramedia.com/uploads/items/111_HOS...
# 1                   /assets/default-images/product.png
# 2    https://cdn.gramedia.com/uploads/items/Biru_Pr...
# 3                   /assets/default-images/product.png
# 4    https://cdn.gramedia.com/uploads/items/Hilangn...
# ..                                                 ...
# 135                 /assets/default-images/product.png
# 136                 /assets/default-images/product.png
# 137                 /assets/default-images/product.png
# 138                 /assets/default-images/product.png
# 139                 /assets/default-images/product.png
#
#                                                   Link
# 0    https://www.gramedia.com/products/cabaca-cara-...
# 1    https://www.gramedia.com/products/living-clean...
# 2    https://www.gramedia.com/products/biru-pram-frasa
# 3    https://www.gramedia.com/products/uncensored-b...
# 4    https://www.gramedia.com/products/hilangnya-sa...
# ..                                                 ...
# 135  https://www.gramedia.com/products/sd-kl-4-pemb...
# 136  https://www.gramedia.com/products/99-kekuatan-...
# 137  https://www.gramedia.com/products/bumi-dan-luk...
# 138  https://www.gramedia.com/products/experiential...
# 139  https://www.gramedia.com/products/sd-kl-2-pemb...
#
# [140 rows x 5 columns]

# %%
# Accessing individual page
title = []
author = []
price = []
desc = []
num_pages = []
date_issue = []
publisher = []

driver = webdriver.Chrome('../../../../../chromedriver.exe')

for i in range(1,3):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            link = "https://www.gramedia.com"+tag.find('a',{"_ngcontent-web-gramedia-c26":""})['href']
            driver.get(link)
            html_ind = driver.page_source
            soup_ind = BeautifulSoup(html_ind, "html.parser")

            title.append( soup_ind.find( 'div', {"class":"book-title"} ).get_text() )
            author.append( soup_ind.find('span',{"class":"title-author"}).get_text() )
            price.append( soup_ind.find('div', {'class':'price-product'}).get_text() )
            desc.append( soup_ind.find('pre').get_text() )
            num_pages.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[0].get_text() )
            date_issue.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[2].get_text() )
            publisher.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[1].get_text() )

        except:
            pass

pages = pd.DataFrame()
pages['Title'] = title
pages['Author'] = author
pages['Price'] = price
pages['Desc'] = desc
pages['Num Pages'] = num_pages
pages['Date Issue'] = date_issue
pages['Publisher'] = publisher

pages
# Out:
# C:\Users\Kurim\AppData\Local\Temp\ipykernel_12500\363428693.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('../../../../../chromedriver.exe')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Hacktiv8_Sheila\learning_journal\phase_0\week_3\day_5\am\web_scrapping.ipynb Cell 13' in <cell line: 39>()
#      <a href='vscode-notebook-cell:/d%3A/Hacktiv8_Sheila/learning_journal/phase_0/week_3/day_5/am/web_scrapping.ipynb#ch0000015?line=36'>37</a> pages['Title'] = title
#      <a href='vscode-notebook-cell:/d%3A/Hacktiv8_Sheila/learning_journal/phase_0/week_3/day_5/am/web_scrapping.ipynb#ch0000015?line=37'>38</a> pages['Author'] = author
# ---> <a href='vscode-notebook-cell:/d%3A/Hacktiv8_Sheila/learning_journal/phase_0/week_3/day_5/am/web_scrapping.ipynb#ch0000015?line=38'>39</a> pages['Price'] = price
#      <a href='vscode-notebook-cell:/d%3A/Hacktiv8_Sheila/learning_journal/phase_0/week_3/day_5/am/web_scrapping.ipynb#ch0000015?line=39'>40</a> pages['Desc'] = desc
#      <a href='vscode-notebook-cell:/d%3A/Hacktiv8_Sheila/learning_journal/phase_0/week_3/day_5/am/web_scrapping.ipynb#ch0000015?line=40'>41</a> pages['Num Pages'] = num_pages
#
# File d:\Programs\Anaconda\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File d:\Programs\Anaconda\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File d:\Programs\Anaconda\lib\site-packages\pandas\core\frame.py:4535, in DataFrame._sanitize_column(self, value)
#    4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
# -> 4535     com.require_length_match(value, self.index)
#    4536 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File d:\Programs\Anaconda\lib\site-packages\pandas\core\common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (0) does not match length of index (16)

# %%
data_multipage.to_csv("result_scrapping.csv")
